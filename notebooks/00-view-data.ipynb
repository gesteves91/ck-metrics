# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
# read the data
df = pd.read_csv("../data/tomcat.csv", index_col=0)

# %%
df.shape
# Out:
# (858, 23)

# %%
df.head()
# Out:
#            version                                             name.1  wmc  dit  noc  cbo  rfc  lcom  ca  ce  npm     lcom3  loc  dam  moa      mfa       cam  ic  cbm        amc  max_cc  avg_cc  bug
# name
# Tomcat  6.0.389418  org.apache.coyote.http11.filters.VoidOutputFilter    8    1    0    6   14    26   2   0    7  1.000000   39  1.0    2  0.00000  0.392857   0    0   3.500000       1  0.7500    0
# Tomcat  6.0.389418                org.apache.el.parser.AstGreaterThan    2    4    0    4    5     1   1   0    2  2.000000   36  0.0    0  0.97561  0.666667   1    1  17.000000       1  0.5000    0
# Tomcat  6.0.389418                          org.apache.coyote.Request   56    1    0   49   89  1310  40   0   56  0.956474  583  1.0   24  0.00000  0.137500   0    0   8.821429       5  1.1964    0
# ...
